# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
raw_data = pd.read_csv('static/chip_dataset.csv')
raw_data
# Out:
#       Unnamed: 0                  Product Type Release Date  \
# 0              0      AMD Athlon 64 3500+  CPU   2007-02-20
# 1              1         AMD Athlon 200GE  CPU   2018-09-06
# 2              2     Intel Core i5-1145G7  CPU   2020-09-02
# 3              3    Intel Xeon E5-2603 v2  CPU   2013-09-01
# 4              4  AMD Phenom II X4 980 BE  CPU   2011-05-03
# ...          ...                      ...  ...          ...
# 4849        4849      NVIDIA Quadro 3000M  GPU   2011-02-22
# 4850        4850            Intel GMA 950  GPU   2005-06-01
# 4851        4851   NVIDIA GeForce GT 320M  GPU   2010-03-03
# 4852        4852   NVIDIA GeForce FX 5200  GPU   2003-03-06
# 4853        4853   NVIDIA GeForce 9300 SE  GPU   2008-06-01
#
#       Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 0                  65.0     45.0             77.0                  122.0
# 1                  14.0     35.0            192.0                 4800.0
# 2                  10.0     28.0              NaN                    NaN
# 3                  22.0     80.0            160.0                 1400.0
# 4                  45.0    125.0            258.0                  758.0
# ...                 ...      ...              ...                    ...
# 4849               40.0     75.0            332.0                 1950.0
# 4850               90.0      7.0              NaN                    NaN
# 4851               40.0     23.0            100.0                  486.0
# 4852              150.0      NaN             65.0                   29.0
# 4853               65.0      NaN             86.0                  210.0
#
#       Freq (MHz)  Foundry  Vendor  FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 0         2200.0  Unknown     AMD          NaN          NaN          NaN
# 1         3200.0  Unknown     AMD          NaN          NaN          NaN
# 2         2600.0    Intel   Intel          NaN          NaN          NaN
# 3         1800.0    Intel   Intel          NaN          NaN          NaN
# 4         3700.0  Unknown     AMD          NaN          NaN          NaN
# ...          ...      ...     ...          ...          ...          ...
# 4849       450.0     TSMC  NVIDIA          NaN        432.0         36.0
# 4850       250.0    Intel   Intel          NaN          NaN          NaN
# 4851       500.0     TSMC  NVIDIA          NaN         52.8          NaN
# 4852       250.0     TSMC  NVIDIA          NaN          NaN          NaN
# 4853       540.0     TSMC  NVIDIA          NaN         20.8          NaN
#
# [4854 rows x 14 columns]

# %%
raw_data.columns
# Out:
# Index(['Unnamed: 0', 'Product', 'Type', 'Release Date', 'Process Size (nm)',
#        'TDP (W)', 'Die Size (mm^2)', 'Transistors (million)', 'Freq (MHz)',
#        'Foundry', 'Vendor', 'FP16 GFLOPS', 'FP32 GFLOPS', 'FP64 GFLOPS'],
#       dtype='object')

# %%
clean_data = raw_data.assign(dict={'Release Date': pd.to_datetime(raw_data['Release Date'])})
clean_data
# Out:
#       Unnamed: 0                  Product Type Release Date  \
# 0              0      AMD Athlon 64 3500+  CPU   2007-02-20
# 1              1         AMD Athlon 200GE  CPU   2018-09-06
# 2              2     Intel Core i5-1145G7  CPU   2020-09-02
# 3              3    Intel Xeon E5-2603 v2  CPU   2013-09-01
# 4              4  AMD Phenom II X4 980 BE  CPU   2011-05-03
# ...          ...                      ...  ...          ...
# 4849        4849      NVIDIA Quadro 3000M  GPU   2011-02-22
# 4850        4850            Intel GMA 950  GPU   2005-06-01
# 4851        4851   NVIDIA GeForce GT 320M  GPU   2010-03-03
# 4852        4852   NVIDIA GeForce FX 5200  GPU   2003-03-06
# 4853        4853   NVIDIA GeForce 9300 SE  GPU   2008-06-01
#
#       Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 0                  65.0     45.0             77.0                  122.0
# 1                  14.0     35.0            192.0                 4800.0
# 2                  10.0     28.0              NaN                    NaN
# 3                  22.0     80.0            160.0                 1400.0
# 4                  45.0    125.0            258.0                  758.0
# ...                 ...      ...              ...                    ...
# 4849               40.0     75.0            332.0                 1950.0
# 4850               90.0      7.0              NaN                    NaN
# 4851               40.0     23.0            100.0                  486.0
# 4852              150.0      NaN             65.0                   29.0
# 4853               65.0      NaN             86.0                  210.0
#
#       Freq (MHz)  Foundry  Vendor  FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS dict
# 0         2200.0  Unknown     AMD          NaN          NaN          NaN  NaN
# 1         3200.0  Unknown     AMD          NaN          NaN          NaN  NaN
# 2         2600.0    Intel   Intel          NaN          NaN          NaN  NaN
# 3         1800.0    Intel   Intel          NaN          NaN          NaN  NaN
# 4         3700.0  Unknown     AMD          NaN          NaN          NaN  NaN
# ...          ...      ...     ...          ...          ...          ...  ...
# 4849       450.0     TSMC  NVIDIA          NaN        432.0         36.0  NaN
# 4850       250.0    Intel   Intel          NaN          NaN          NaN  NaN
# 4851       500.0     TSMC  NVIDIA          NaN         52.8          NaN  NaN
# 4852       250.0     TSMC  NVIDIA          NaN          NaN          NaN  NaN
# 4853       540.0     TSMC  NVIDIA          NaN         20.8          NaN  NaN
#
# [4854 rows x 15 columns]

# %%
fig = px.scatter(clean_data, x='Release Date', y='Transistors (million)', log_y=True)
fig

# %%
idxmax_per_year = (raw_data
 .assign(Year = pd.to_datetime(raw_data['Release Date']).dt.year)
).groupby('Year')['Transistors (million)'].idxmax()
max_per_year = raw_data.loc[idxmax_per_year].sort_values('Release Date')
max_per_year
# Out:
#       Unnamed: 0                             Product Type Release Date  \
# 3074        3074        Sony Playstation 2 GPU 250nm  GPU   2000-03-04
# 1262        1262                 AMD Athlon 64 3700+  CPU   2001-01-01
# 226          226                 Intel Pentium 4 2.0  CPU   2002-01-07
# 50            50                     Intel Xeon 3.20  CPU   2003-10-06
# 1613        1613                     Intel Xeon 3.20  CPU   2004-02-01
# 2361        2361  ATI Radeon X1800 CrossFire Edition  GPU   2005-12-20
# 388          388                    Intel Xeon 7130M  CPU   2006-08-27
# 1705        1705         Intel Core 2 Extreme QX9650  CPU   2007-11-30
# 2437        2437       NVIDIA GeForce GTX 260 Rev. 2  GPU   2008-07-23
# 2652        2652                  ATI Radeon HD 5970  GPU   2009-11-18
# 2213        2213              NVIDIA GeForce GTX 470  GPU   2010-03-26
# 2495        2495                  AMD Radeon HD 7970  GPU   2011-12-22
# 3209        3209                  NVIDIA Tesla K20Xm  GPU   2012-11-12
# 2303        2303                   NVIDIA Tesla K40s  GPU   2013-11-22
# 4727        4727                    NVIDIA Tesla K80  GPU   2014-11-17
# 2998        2998                  AMD Radeon R9 Nano  GPU   2015-08-27
# 2657        2657        NVIDIA Tesla P100 PCIe 12 GB  GPU   2016-06-20
# 2975        2975                      NVIDIA TITAN V  GPU   2017-12-07
# 2211        2211        NVIDIA Tesla V100 SXM2 32 GB  GPU   2018-03-27
# 2252        2252       NVIDIA Tesla V100S PCIe 32 GB  GPU   2019-11-26
# 2674        2674              NVIDIA A100 SXM4 80 GB  GPU   2020-11-16
# 2487        2487                    NVIDIA PG506-232  GPU   2021-04-12
#
#       Process Size (nm)  TDP (W)  Die Size (mm^2)  Transistors (million)  \
# 3074              250.0     79.0            279.0                   54.0
# 1262               90.0     89.0            199.0                  233.0
# 226               130.0     92.0            146.0                  125.0
# 50                130.0     97.0            237.0                  286.0
# 1613              130.0     97.0            237.0                  286.0
# 2361               90.0    113.0            288.0                  321.0
# 388                65.0    150.0            435.0                 1328.0
# 1705               45.0    130.0            107.0                  820.0
# 2437               55.0    182.0            470.0                 1400.0
# 2652               40.0    294.0            334.0                 2154.0
# 2213               40.0    215.0            529.0                 3100.0
# 2495               28.0    250.0            352.0                 4313.0
# 3209               28.0    235.0            561.0                 7080.0
# 2303               28.0    245.0            561.0                 7080.0
# 4727               28.0    300.0            561.0                 7100.0
# 2998               28.0    175.0            596.0                 8900.0
# 2657               16.0    250.0            610.0                15300.0
# 2975               12.0    250.0            815.0                21100.0
# 2211               12.0    250.0            815.0                21100.0
# 2252               12.0    250.0            815.0                21100.0
# 2674                7.0    400.0            826.0                54200.0
# 2487                7.0    165.0            826.0                54200.0
#
#       Freq (MHz)  Foundry  Vendor  FP16 GFLOPS  FP32 GFLOPS  FP64 GFLOPS
# 3074       147.0     Sony   Other          NaN          NaN          NaN
# 1262      2200.0  Unknown     AMD          NaN          NaN          NaN
# 226       2000.0    Intel   Intel          NaN          NaN          NaN
# 50        3200.0    Intel   Intel          NaN          NaN          NaN
# 1613      3200.0    Intel   Intel          NaN          NaN          NaN
# 2361       600.0     TSMC     ATI          NaN          NaN          NaN
# 388       3200.0    Intel   Intel          NaN          NaN          NaN
# 1705      3000.0    Intel   Intel          NaN          NaN          NaN
# 2437       576.0     TSMC  NVIDIA          NaN        476.9        59.62
# 2652       725.0     TSMC     ATI          NaN       2320.0       464.00
# 2213       608.0     TSMC  NVIDIA          NaN       1089.0       136.10
# 2495       925.0     TSMC     AMD          NaN       3789.0       947.20
# 3209       732.0     TSMC  NVIDIA          NaN       3935.0      1312.00
# 2303       745.0     TSMC  NVIDIA          NaN       5046.0      1682.00
# 4727       562.0     TSMC  NVIDIA          NaN       4113.0      1371.00
# 2998      1000.0     TSMC     AMD       8192.0       8192.0       512.00
# 2657      1190.0     TSMC  NVIDIA      19050.0       9526.0      4763.00
# 2975      1200.0     TSMC  NVIDIA      29800.0      14900.0      7450.00
# 2211      1290.0     TSMC  NVIDIA      31330.0      15670.0      7834.00
# 2252      1245.0     TSMC  NVIDIA      32710.0      16350.0      8177.00
# 2674      1095.0     TSMC  NVIDIA      77970.0      19490.0      9746.00
# 2487       930.0     TSMC  NVIDIA      10320.0      10320.0      5161.00

# %%
fig = px.scatter(max_per_year, x='Release Date', y='Transistors (million)', log_y=True)
fig
