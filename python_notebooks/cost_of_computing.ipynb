# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../static/cost_of_computing.csv")

# %%
df.sort_values(by = "Year", inplace=True)

# %%
data = df.fillna(0)

# %%
data.sort_values(by="Year", inplace=True)

# %%
data
# Out:
#    Entity      Code  Year        memory     flash   disk_drives    ssd
# 44  World  OWID_WRL  1956  0.000000e+00       0.0  9.200000e+09    0.0
# 0   World  OWID_WRL  1957  4.110418e+14       0.0  0.000000e+00    0.0
# 1   World  OWID_WRL  1959  6.794772e+13       0.0  7.600000e+09    0.0
# 2   World  OWID_WRL  1960  5.242880e+12       0.0  3.600000e+09    0.0
# 45  World  OWID_WRL  1964  0.000000e+00       0.0  3.518620e+09    0.0
# 3   World  OWID_WRL  1965  2.642412e+12       0.0  0.000000e+00    0.0
# 46  World  OWID_WRL  1966  0.000000e+00       0.0  1.047260e+09    0.0
# 4   World  OWID_WRL  1970  7.340030e+11       0.0  2.597000e+08    0.0
# 5   World  OWID_WRL  1973  3.993600e+11       0.0  0.000000e+00    0.0
# 6   World  OWID_WRL  1974  3.145730e+11       0.0  1.850000e+08    0.0
# 7   World  OWID_WRL  1975  4.992000e+10       0.0  0.000000e+00    0.0
# 8   World  OWID_WRL  1976  2.304000e+10       0.0  0.000000e+00    0.0
# ...

# %%
data.to_csv('../static/cost_of_computing.csv', index=False)
